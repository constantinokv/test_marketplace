# %%
import pandas as pd
import numpy as np
import os

# Crear datos de ejemplo
products_data = {
    'product_id': range(1, 1001),
    'title': [
        'iPhone 13 Pro 128GB',
        'Samsung Galaxy S21',
        'MacBook Pro 14"',
        'Gaming Mouse RGB',
        'Wireless Earbuds'
    ] * 200,  # Multiplicar para tener 1000 productos
    'description': [
        'Latest Apple iPhone with Pro camera system',
        'Android flagship with amazing display',
        'Powerful laptop for professionals',
        'High precision gaming mouse with RGB lighting',
        'Premium wireless earbuds with noise cancellation'
    ] * 200,
    'category': [
        'Electronics/Phones',
        'Electronics/Phones',
        'Electronics/Laptops',
        'Electronics/Accessories',
        'Electronics/Audio'
    ] * 200,
    'price': np.random.uniform(100, 2000, 1000),
    'rating': np.random.uniform(3.5, 5.0, 1000),
    'reviews_count': np.random.randint(10, 1000, 1000),
    'sales_last_30_days': np.random.randint(0, 200, 1000),
    'stock': np.random.randint(0, 100, 1000),
    'seller_rating': np.random.uniform(4.0, 5.0, 1000),
    'shipping_time_days': np.random.randint(1, 10, 1000)
}

# Crear DataFrame
df = pd.DataFrame(products_data)

# Guardar como CSV
df.to_csv('products.csv', index=False)

# Imprimir muestra
print(df.head())
print("\nInformación del Dataset:")
print(df.info())
# Out:
#    product_id                title  \
# 0           1  iPhone 13 Pro 128GB
# 1           2   Samsung Galaxy S21
# 2           3      MacBook Pro 14"
# 3           4     Gaming Mouse RGB
# 4           5     Wireless Earbuds
#
#                                         description                 category  \
# 0        Latest Apple iPhone with Pro camera system       Electronics/Phones
# 1             Android flagship with amazing display       Electronics/Phones
# 2                 Powerful laptop for professionals      Electronics/Laptops
# 3     High precision gaming mouse with RGB lighting  Electronics/Accessories
# 4  Premium wireless earbuds with noise cancellation        Electronics/Audio
#
#         price    rating  reviews_count  sales_last_30_days  stock  \
# 0  392.500768  3.572427            312                  97     61
# 1  883.924537  4.065703            616                  22      7
# 2  596.977816  3.626405            449                  79     88
# ...
